# %%
# !nvidia-smi
# Out:
# Fri May 28 12:04:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 451.67       Driver Version: 451.67       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce MX150      WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   51C    P8    N/A /  N/A |     64MiB /  2048MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()

from tensorflow import keras

import matplotlib.pyplot as plt
import numpy as np

import os

# %%
image_size = 224
target_size = (image_size, image_size)
input_shape = (image_size, image_size, 3)

batch_size = 32
epochs = 25

# %%
base_dir = r"D:\plant disease detection\New Plant Diseases Dataset(Augmented)"
train_dir = os.path.join(base_dir,"train")
test_dir = os.path.join(base_dir,"valid")

# %%
train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255.0,
                                                             shear_range = 0.2,
                                                             zoom_range = 0.2,
                                                             width_shift_range = 0.2,
                                                             height_shift_range = 0.2,
                                                             fill_mode="nearest")

test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size = (image_size, image_size),
                                               batch_size = batch_size,
                                               class_mode = "categorical")

test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size = (image_size, image_size),
                                             batch_size = batch_size,
                                             class_mode = "categorical")
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.

# %%
categories = list(train_data.class_indices.keys())
print(train_data.class_indices)
# Out:
# {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Blueberry___healthy': 4, 'Cherry_(including_sour)___Powdery_mildew': 5, 'Cherry_(including_sour)___healthy': 6, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7, 'Corn_(maize)___Common_rust_': 8, 'Corn_(maize)___Northern_Leaf_Blight': 9, 'Corn_(maize)___healthy': 10, 'Grape___Black_rot': 11, 'Grape___Esca_(Black_Measles)': 12, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13, 'Grape___healthy': 14, 'Orange___Haunglongbing_(Citrus_greening)': 15, 'Peach___Bacterial_spot': 16, 'Peach___healthy': 17, 'Pepper,_bell___Bacterial_spot': 18, 'Pepper,_bell___healthy': 19, 'Potato___Early_blight': 20, 'Potato___Late_blight': 21, 'Potato___healthy': 22, 'Raspberry___healthy': 23, 'Soybean___healthy': 24, 'Squash___Powdery_mildew': 25, 'Strawberry___Leaf_scorch': 26, 'Strawberry___healthy': 27, 'Tomato___Bacterial_spot': 28, 'Tomato___Early_blight': 29, 'Tomato___Late_blight': 30, 'Tomato___Leaf_Mold': 31, 'Tomato___Septoria_leaf_spot': 32, 'Tomato___Spider_mites Two-spotted_spider_mite': 33, 'Tomato___Target_Spot': 34, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35, 'Tomato___Tomato_mosaic_virus': 36, 'Tomato___healthy': 37}

# %%
import json
with open('class_indices.json','w') as f:
  json.dump(train_data.class_indices, f)

from IPython.display import FileLink
FileLink(r'class_indices.json')
# Out:
# C:\Users\Asus\Project\class_indices.json

# %%
base_model = tf.keras.applications.MobileNet(weights = "imagenet",
                                             include_top = False,
                                             input_shape = input_shape)

base_model.trainable = False

# %%
inputs = keras.Input(shape = input_shape)

x = base_model(inputs, training = False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(len(categories), 
                          activation="softmax")(x)

model = keras.Model(inputs = inputs, 
                    outputs = x, 
                    name="LeafDisease_MobileNet")

# %%
optimizer = tf.keras.optimizers.Adam()

model.compile(optimizer = optimizer,
              loss = tf.keras.losses.CategoricalCrossentropy(from_logits = True),
              metrics=[keras.metrics.CategoricalAccuracy(), 
                       'accuracy'])

# %%
history = model.fit(train_data,
                    validation_data=test_data,
                    epochs=epochs,
                    steps_per_epoch=150,
                    validation_steps=100)
# Out:
# Epoch 1/25
# 150/150 [==============================] - 199s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.2067 - categorical_accuracy: 0.9302 - acc: 0.9302 - val_loss: 0.1517 - val_categorical_accuracy: 0.9513 - val_acc: 0.9513
# Epoch 2/25
# 150/150 [==============================] - 200s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1901 - categorical_accuracy: 0.9354 - acc: 0.9354 - val_loss: 0.1599 - val_categorical_accuracy: 0.9469 - val_acc: 0.9469
# Epoch 3/25
# 150/150 [==============================] - 200s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.2111 - categorical_accuracy: 0.9296 - acc: 0.9296 - val_loss: 0.1708 - val_categorical_accuracy: 0.9425 - val_acc: 0.9425
# Epoch 4/25
# 150/150 [==============================] - 208s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.2101 - categorical_accuracy: 0.9290 - acc: 0.9290 - val_loss: 0.1473 - val_categorical_accuracy: 0.9509 - val_acc: 0.9509
# Epoch 5/25
# 150/150 [==============================] - 216s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1970 - categorical_accuracy: 0.9325 - acc: 0.9325 - val_loss: 0.1510 - val_categorical_accuracy: 0.9459 - val_acc: 0.9459
# Epoch 6/25
# 150/150 [==============================] - 201s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.2066 - categorical_accuracy: 0.9321 - acc: 0.9321 - val_loss: 0.1532 - val_categorical_accuracy: 0.9481 - val_acc: 0.9481
# Epoch 7/25
# 150/150 [==============================] - 211s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1928 - categorical_accuracy: 0.9375 - acc: 0.9375 - val_loss: 0.1495 - val_categorical_accuracy: 0.9509 - val_acc: 0.9509
# Epoch 8/25
# 150/150 [==============================] - 207s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1963 - categorical_accuracy: 0.9337 - acc: 0.9337 - val_loss: 0.1613 - val_categorical_accuracy: 0.9447 - val_acc: 0.9447
# Epoch 9/25
# 150/150 [==============================] - 200s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1986 - categorical_accuracy: 0.9319 - acc: 0.9319 - val_loss: 0.1632 - val_categorical_accuracy: 0.9459 - val_acc: 0.9459
# Epoch 10/25
# 150/150 [==============================] - 196s 1s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1946 - categorical_accuracy: 0.9350 - acc: 0.9350 - val_loss: 0.1313 - val_categorical_accuracy: 0.9575 - val_acc: 0.9575
# Epoch 11/25
# 150/150 [==============================] - 215s 1s/step - batch: 74.5000 - size: 31.9400 - loss: 0.2121 - categorical_accuracy: 0.9305 - acc: 0.9305 - val_loss: 0.1445 - val_categorical_accuracy: 0.9528 - val_acc: 0.9528
# Epoch 12/25
# 150/150 [==============================] - 254s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1837 - categorical_accuracy: 0.9377 - acc: 0.9377 - val_loss: 0.1455 - val_categorical_accuracy: 0.9541 - val_acc: 0.9541
# Epoch 13/25
# 150/150 [==============================] - 297s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1980 - categorical_accuracy: 0.9325 - acc: 0.9325 - val_loss: 0.1537 - val_categorical_accuracy: 0.9478 - val_acc: 0.9478
# Epoch 14/25
# 150/150 [==============================] - 316s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1974 - categorical_accuracy: 0.9348 - acc: 0.9348 - val_loss: 0.1363 - val_categorical_accuracy: 0.9578 - val_acc: 0.9578
# Epoch 15/25
# 150/150 [==============================] - 279s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.2094 - categorical_accuracy: 0.9315 - acc: 0.9315 - val_loss: 0.1328 - val_categorical_accuracy: 0.9597 - val_acc: 0.9597
# Epoch 16/25
# 150/150 [==============================] - 274s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1864 - categorical_accuracy: 0.9342 - acc: 0.9342 - val_loss: 0.1373 - val_categorical_accuracy: 0.9559 - val_acc: 0.9559
# Epoch 17/25
# 150/150 [==============================] - 294s 2s/step - batch: 74.5000 - size: 31.9400 - loss: 0.2025 - categorical_accuracy: 0.9301 - acc: 0.9301 - val_loss: 0.1524 - val_categorical_accuracy: 0.9481 - val_acc: 0.9481
# Epoch 18/25
# 150/150 [==============================] - 294s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1835 - categorical_accuracy: 0.9377 - acc: 0.9377 - val_loss: 0.1467 - val_categorical_accuracy: 0.9506 - val_acc: 0.9506
# Epoch 19/25
# 150/150 [==============================] - 296s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1646 - categorical_accuracy: 0.9456 - acc: 0.9456 - val_loss: 0.1381 - val_categorical_accuracy: 0.9519 - val_acc: 0.9519
# Epoch 20/25
# 150/150 [==============================] - 297s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1920 - categorical_accuracy: 0.9367 - acc: 0.9367 - val_loss: 0.1431 - val_categorical_accuracy: 0.9491 - val_acc: 0.9491
# Epoch 21/25
# 150/150 [==============================] - 298s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1865 - categorical_accuracy: 0.9369 - acc: 0.9369 - val_loss: 0.1468 - val_categorical_accuracy: 0.9519 - val_acc: 0.9519
# Epoch 22/25
# 150/150 [==============================] - 288s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1797 - categorical_accuracy: 0.9373 - acc: 0.9373 - val_loss: 0.1325 - val_categorical_accuracy: 0.9569 - val_acc: 0.9569
# Epoch 23/25
# 150/150 [==============================] - 290s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.1776 - categorical_accuracy: 0.9406 - acc: 0.9406 - val_loss: 0.1500 - val_categorical_accuracy: 0.9497 - val_acc: 0.9497
# Epoch 24/25
# 150/150 [==============================] - 275s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.2006 - categorical_accuracy: 0.9367 - acc: 0.9367 - val_loss: 0.1261 - val_categorical_accuracy: 0.9588 - val_acc: 0.9588
# Epoch 25/25
# 150/150 [==============================] - 263s 2s/step - batch: 74.5000 - size: 32.0000 - loss: 0.2042 - categorical_accuracy: 0.9296 - acc: 0.9296 - val_loss: 0.1365 - val_categorical_accuracy: 0.9538 - val_acc: 0.9538

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

fig = plt.figure(figsize=(10,6))
plt.plot(epochs,loss,c="red",label="Training")
plt.plot(epochs,val_loss,c="blue",label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']

epochs = range(len(acc))

fig = plt.figure(figsize=(10,6))
plt.plot(epochs,acc,c="red",label="Training")
plt.plot(epochs,val_acc,c="blue",label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
model.save('plant_disease')
